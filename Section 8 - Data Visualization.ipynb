# %% [markdown]
# # Author : Deepak Kothari
# ## Reference - Udemy Data Visualization Course

# %%
# Standard
import numpy as np
import pandas as pd

from numpy.random import randn

# %%
# Stats

from scipy import stats

# %%
# Plotting

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
url = 'https://en.wikipedia.org/wiki/Histogram'

# %%
import webbrowser as web

web.open(url)
# Out:
# True

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 3.,  6., 12., 16., 15., 20., 10., 12.,  3.,  3.]),
#  array([-2.13489706, -1.6753352 , -1.21577334, -0.75621148, -0.29664962,
#          0.16291224,  0.6224741 ,  1.08203596,  1.54159783,  2.00115969,
#          2.46072155]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 2.,  8., 10., 16., 20., 12.,  4.,  6.,  0.,  2.]),
#  array([-2.40060323, -1.84354179, -1.28648034, -0.72941889, -0.17235744,
#          0.38470401,  0.94176545,  1.4988269 ,  2.05588835,  2.6129498 ,
#          3.17001125]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, color='indianred', alpha=0.5, bins=20)
plt.hist(dataset2, normed=True, alpha=0.5, bins=20)
# Out:
# C:\Users\deepa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\deepa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# (array([0.04487835, 0.04487835, 0.0897567 , 0.26927011, 0.0897567 ,
#         0.35902682, 0.22439176, 0.49366188, 0.40390517, 0.49366188,
#         0.22439176, 0.31414847, 0.13463506, 0.04487835, 0.26927011,
#         0.        , 0.        , 0.        , 0.04487835, 0.04487835]),
#  array([-2.40060323, -2.12207251, -1.84354179, -1.56501106, -1.28648034,
#         -1.00794961, -0.72941889, -0.45088817, -0.17235744,  0.10617328,
#          0.38470401,  0.66323473,  0.94176545,  1.22029618,  1.4988269 ,
#          1.77735763,  2.05588835,  2.33441907,  2.6129498 ,  2.89148052,
#          3.17001125]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(dataset1, density=True, color='indianred', alpha=0.5, bins=20)
plt.hist(dataset2, density=True, alpha=0.5, bins=20)
# Out:
# (array([0.04487835, 0.04487835, 0.0897567 , 0.26927011, 0.0897567 ,
#         0.35902682, 0.22439176, 0.49366188, 0.40390517, 0.49366188,
#         0.22439176, 0.31414847, 0.13463506, 0.04487835, 0.26927011,
#         0.        , 0.        , 0.        , 0.04487835, 0.04487835]),
#  array([-2.40060323, -2.12207251, -1.84354179, -1.56501106, -1.28648034,
#         -1.00794961, -0.72941889, -0.45088817, -0.17235744,  0.10617328,
#          0.38470401,  0.66323473,  0.94176545,  1.22029618,  1.4988269 ,
#          1.77735763,  2.05588835,  2.33441907,  2.6129498 ,  2.89148052,
#          3.17001125]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)

# %%
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1,data2,kind='hex')

# %% [markdown]
# # Kernel Density Estimation plots

# %%
dataset = randn(25)

# %%
sns.rugplot(dataset)
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
plt.hist(dataset, alpha=0.3)
sns.rugplot(dataset)

# %%
sns.rugplot(dataset)

x_min = dataset.min() - 2
x_max = dataset.max() + 2

x_axis = np.linspace(x_min,x_max,100)

bandwidth = ((4*dataset.std()**5) / (3*len(dataset)))**0.2

kernel_list = []

for data_point in dataset :
    
    # Create a kernel for each point and append in the kernel list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    # Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * 0.4
    
    plt.plot(x_axis, kernel,color='grey', alpha=0.5)
    
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
sum_of_kde = np.sum(kernel_list, axis=0)

fig = plt.plot(x_axis, sum_of_kde, color='indianred')

sns.rugplot(dataset)

plt.yticks([])

plt.suptitle('Sum of basis function')
# Out:
# Text(0.5, 0.98, 'Sum of basis function')

# %%
sns.kdeplot(dataset)

# %%
sns.rugplot(dataset,color='black')

for bw in np.arange(0.5,2.0,0.25) :
    sns.kdeplot(dataset,bw=bw,label=bw,lw=1.8)

# %%
url = 'https://en.wikipedia.org/wiki/Kernel_density_estimation'

# %%
url = 'https://en.wikipedia.org/wiki/Kernel_(statistics)'

# %%
kernel_options = ['biw','cos','epa','gau','tri','triw']

for kern in kernel_options :
    sns.kdeplot(dataset,kernel=kern,label=kern,shade=True)

# %%
kernel_options = ['biw','cos','epa','gau','tri','triw']

for kern in kernel_options :
    sns.kdeplot(dataset,kernel=kern,label=kern)

# %%
kernel_options = ['biw','cos','epa','gau','tri','triw']

for kern in kernel_options :
    sns.kdeplot(dataset,kernel=kern,label=kern,shade=True,vertical=True)

# %%
sns.kdeplot(dataset,cumulative=True)

# %%
mean = [0,0]
cov = [[1,0],[0,100]]

dataset2 = np.random.multivariate_normal(mean,cov,1000)

dframe = pd.DataFrame(dataset2,columns=['X','Y'])

sns.kdeplot(dframe)
# Out:
# C:\Users\deepa\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.kdeplot(dframe.X,dframe.Y,shade=True)

# %%
sns.kdeplot(dframe,bw=1)
# Out:
# C:\Users\deepa\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.kdeplot(dframe,bw='silverman')
# Out:
# C:\Users\deepa\Anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.jointplot('X','Y',dframe,kind='kde')

# %% [markdown]
# # Combining Plot Styles

# %%
dataset = randn(100)

# %%
sns.distplot(dataset,bins=25)

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False)

# %%
sns.distplot(dataset,bins=25,
            kde_kws={'color':'indianred','label':'KDE_PLOT'},
            hist_kws={'color':'blue','label':'HIST'})

# %%
from pandas import Series

# %%
ser1 = Series(dataset,name='My_Data')

# %%
ser1
# Out:
# 0    -0.721907
# 1     1.798247
# 2     0.996976
# 3    -0.170631
# 4    -0.722167
# 5     0.463483
# 6     0.551710
# 7     0.449177
# 8    -0.930926
# 9     1.609218
# 10   -0.914464
# 11   -0.465915
# 12    1.311726
# 13    1.656011
# 14    0.375227
# 15    0.847543
# 16    0.452681
# 17    2.223310
# 18   -0.981682
# 19   -1.058112
# 20   -0.741240
# 21    0.348247
# 22    0.194404
# 23   -1.515017
# 24    1.187335
# 25   -1.782743
# 26   -0.449711
# 27   -0.729514
# 28    1.088686
# 29    0.871799
#         ...
# 70   -0.083272
# 71   -0.281319
# 72    0.847591
# 73   -0.839214
# 74    0.813175
# 75    0.579962
# 76    0.056576
# 77   -0.760148
# 78   -0.385212
# 79   -0.458002
# 80    0.199384
# 81   -0.022195
# 82   -1.145450
# 83    0.346199
# 84   -0.232587
# 85   -1.022299
# 86   -1.290703
# 87   -0.556053
# 88   -1.524200
# 89    1.552936
# 90   -1.314695
# 91   -1.028966
# 92   -0.641743
# 93    0.515313
# 94    0.125360
# 95    0.132774
# 96    0.298055
# 97   -0.996466
# 98    1.894669
# 99   -0.295284
# Name: My_Data, Length: 100, dtype: float64

# %%
sns.distplot(ser1,bins=25)

# %% [markdown]
# # Box and Violin Plots

# %%
url = 'https://en.wikipedia.org/wiki/Box_plot'

# %%
data1 = randn(100)
data2 = randn(100)

# %%
sns.boxplot([data1,data2],orient='v')

# %%
sns.boxplot([data1,data2],whis=np.inf)

# %%
sns.boxplot(data1,orient='v')

# %%
# Normal Dist
data1 = stats.norm(0,5).rvs(100)

# %%
# Two Gamma Dist, concatenated together

data2 = np.concatenate([stats.gamma(5).rvs(50)-1,
                       -1*stats.gamma(5).rvs(50)])

# %%
sns.boxplot(data1,whis=np.inf)

# %%
sns.boxplot(data2,whis=np.inf)

# %%
sns.violinplot(data1)

# %%
sns.violinplot(data2)

# %%
sns.violinplot(data1,bw=0.01)

# %%
sns.violinplot(data2,bw=0.01)

# %%
sns.violinplot(data1,inner='stick',orient='v')

# %% [markdown]
# # Regression Plot

# %%
tips = sns.load_dataset('tips')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill','tip',tips)

# %%
sns.lmplot('total_bill','tip',tips,
          scatter_kws={'marker':'0','color':'indianred'},
          line_kws={'linewidth':1,'color':'blue'})

# %%
sns.lmplot('total_bill','tip',tips, order=4,
          scatter_kws={'marker':'0','color':'indianred'},
          line_kws={'linewidth':1,'color':'blue'})

# %%
sns.lmplot('total_bill','tip',tips,fit_reg=False)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pect'] = 100 * (tips['tip']/tips['total_bill'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
tips.shape
# Out:
# (244, 8)

# %%
sns.lmplot('size','tip_pect',tips)

# %%
sns.lmplot('size','tip_pect',tips,x_jitter=0.1)

# %%
sns.lmplot('size','tip_pect',tips,x_estimator=np.mean)

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='sex',markers=['x','o'])

# %%
sns.lmplot('total_bill','tip_pect',tips,hue='day')

# %%
sns.lmplot('total_bill','tip_pect',tips,lowess=True,line_kws={'color':'black','linewidth':5})

# %%
sns.regplot('total_bill','tip_pect',tips)

# %%
fig, (axis1,axis2) = plt.subplots(1,2,sharey=True)

sns.regplot('total_bill','tip_pect',tips,ax=axis1)
sns.violinplot(tips['size'],tips['tip_pect'],palette ='Reds_r',ax=axis2)

# %% [markdown]
# # Heatmaps and Clustered Matrices

# %%
flights_dframe = sns.load_dataset('flights')

# %%
flights_dframe.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights_dframe.shape
# Out:
# (144, 3)

# %%
flights_dframe = flights_dframe.pivot('month','year','passengers')

# %%
flights_dframe.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
flights_dframe.shape
# Out:
# (12, 12)

# %%
sns.heatmap(flights_dframe)

# %%
sns.heatmap(flights_dframe,annot=True,fmt='d')

# %%
sns.heatmap(flights_dframe,center=flights_dframe.loc['January',1955])

# %%
f, (axis1,axis2) = plt.subplots(2,1)

yearly_flights = flights_dframe.sum()

years = Series(yearly_flights.index.values)
years = pd.DataFrame(years)

flights = Series(yearly_flights.values)
flights = pd.DataFrame(flights)

year_dframe = pd.concat((years,flights),axis=1)
year_dframe.columns=['Year','Flights']

sns.barplot('Year',y='Flights',data=year_dframe,ax=axis1)

sns.heatmap(flights_dframe,cmap='Blues',ax=axis2,cbar_kws={'orientation':'horizontal'})

# %%
flights_dframe.sum()
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# dtype: int64

# %%
year_dframe
# Out:
#     Year  Flights
# 0   1949     1520
# 1   1950     1676
# 2   1951     2042
# 3   1952     2364
# 4   1953     2700
# 5   1954     2867
# 6   1955     3408
# 7   1956     3939
# 8   1957     4421
# 9   1958     4572
# 10  1959     5140
# 11  1960     5714

# %%
sns.clustermap(flights_dframe)

# %%
sns.clustermap(flights_dframe,col_cluster=False)

# %%
sns.clustermap(flights_dframe,standard_scale=1)

# %%
sns.clustermap(flights_dframe,standard_scale=0)

# %%
sns.clustermap(flights_dframe,z_score=1)
